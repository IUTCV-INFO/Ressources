# %% [markdown]
# # Le module sympy (calcul formel)

# %%
from sympy import *

# %%
x=symbols("x")

# %%
f=S("2/3*x**2+3*x-5")
print(f)
f
# Out:
# 2*x**2/3 + 3*x - 5
# 2*x**2/3 + 3*x - 5

# %% [markdown]
# ## Calcul littéral

# %%
2*x+3*x
# Out:
# 5*x

# %%
factor(x**2+5*x-6)
# Out:
# (x - 1)*(x + 6)

# %%
simplify(1/x+1/(x+1))
# Out:
# (2*x + 1)/(x*(x + 1))

# %%
expand((x-2)*(x+3))
# Out:
# x**2 + x - 6

# %%
f=x**2+5*x-6
f.subs(x,sqrt(2))
# Out:
# -4 + 5*sqrt(2)

# %% [markdown]
# ## Dérivation et intégration

# %%
g =diff(f,x)
print(g)
g
# Out:
# 4*x/3 + 3
# 4*x/3 + 3

# %%
integrate(g,x)
# Out:
# 2*x**2/3 + 3*x

# %% [markdown]
# ## Les fractions

# %%
Rational("2/7")+Rational("4/9")
# Out:
# 46/63

# %%
a=S("2/7+4/9")
simplify(a)
# Out:
# 46/63

# %% [markdown]
# ## Les matrices

# %%
A = Matrix([[1,2],[4,2]])
A
# Out:
# Matrix([
# [1, 2],
# [4, 2]])

# %%
B=Matrix([[1,3],[2,1]])
B
# Out:
# Matrix([
# [1, 3],
# [2, 1]])

# %%
A+B
# Out:
# Matrix([
# [2, 5],
# [6, 3]])

# %%
A*B
# Out:
# Matrix([
# [5,  5],
# [8, 14]])

# %%
5*A
# Out:
# Matrix([
# [ 5, 10],
# [20, 10]])

# %%
A**(-1)
# Out:
# Matrix([
# [-1/3,  1/3],
# [ 2/3, -1/6]])

# %%
A.transpose()
# Out:
# Matrix([
# [1, 4],
# [2, 2]])
